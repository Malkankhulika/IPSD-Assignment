# %%
# !pip install pandas
# !pip install numpy
# !pip install seaborn
# !pip install matplotib.pyplot
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel 'Python 3.12.6' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# !pip install openpyxl
# !pip install wordcloud
# !pip install imblearn
# Out:
# ...
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
from sklearn.impute import KNNImputer
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE
from wordcloud import WordCloud

# %%
warmindo = pd.read_csv ("Penjualan warmindo.csv")
warmindo
# Out:
#       id  invoice_id tanggal_transaksi  customer_id               nama_produk  \
# 0      1           1           4/11/22           44      Indomie Ayam Spesial
# 1      2           2            8/1/22           10      Indomie Ayam Spesial
# 2      3           3            4/3/22           62  Indomie Rasa Soto Betawi
# 3      4           4           3/19/22           48  Indomie Rasa Soto Padang
# 4      5           5           4/29/22           87   Indomie Rasa Sop Buntut
# ..   ...         ...               ...          ...                       ...
# 494  495         495           5/17/22           11         Indomie Baso Sapi
# 495  496         496            6/6/22           55    Indomie Goreng Spesial
# 496  497         497           7/14/22           25    Indomie Goreng Rendang
# 497  498         498           8/22/22           39      Indomie Goreng Pedas
# 498  499         499           6/21/22           79          Indomie Soto Mie
#
# ...

# %%
# menampilkan 5 data pertam/teratas
warmindo.head()
# Out:
#    id  invoice_id tanggal_transaksi  customer_id               nama_produk  \
# 0   1           1           4/11/22           44      Indomie Ayam Spesial
# 1   2           2            8/1/22           10      Indomie Ayam Spesial
# 2   3           3            4/3/22           62  Indomie Rasa Soto Betawi
# 3   4           4           3/19/22           48  Indomie Rasa Soto Padang
# 4   5           5           4/29/22           87   Indomie Rasa Sop Buntut
#
#   jenis_produk kategori_produk  quantity  harga_jual jenis_pembayaran  \
# 0     mie-kuah         makanan         2        9000         QRIS-OVO
# 1     mie-kuah         makanan         2        9000             CASH
# 2     mie-kuah         makanan         1       10000      QRIS-OTHERS
# 3     mie-kuah         makanan         3       10000             CASH
# 4     mie-kuah         makanan         2       10000         QRIS-OVO
#
#   jenis_pesanan  nilai_penjualan
# 0       Dine-In            18000
# ...

# %%
warmindo.tail()
# Out:
#       id  invoice_id tanggal_transaksi  customer_id             nama_produk  \
# 494  495         495           5/17/22           11       Indomie Baso Sapi
# 495  496         496            6/6/22           55  Indomie Goreng Spesial
# 496  497         497           7/14/22           25  Indomie Goreng Rendang
# 497  498         498           8/22/22           39    Indomie Goreng Pedas
# 498  499         499           6/21/22           79        Indomie Soto Mie
#
#     jenis_produk kategori_produk  quantity  harga_jual jenis_pembayaran  \
# 494     mie-kuah         makanan         1        9000             CASH
# 495   mie-goreng         makanan         1        9000       QRIS-GOPAY
# 496   mie-goreng         makanan         2        9000       QRIS-GOPAY
# 497   mie-goreng         makanan         2        9000        QRIS-DANA
# 498     mie-kuah         makanan         1        9000         QRIS-OVO
#
#     jenis_pesanan  nilai_penjualan
# 494      Delivery             9000
# ...

# %%
warmindo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 499 entries, 0 to 498
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 499 non-null    int64
#  1   invoice_id         499 non-null    int64
#  2   tanggal_transaksi  499 non-null    object
#  3   customer_id        499 non-null    int64
#  4   nama_produk        499 non-null    object
#  5   jenis_produk       499 non-null    object
#  6   kategori_produk    499 non-null    object
#  7   quantity           499 non-null    int64
#  8   harga_jual         499 non-null    int64
#  9   jenis_pembayaran   499 non-null    object
#  10  jenis_pesanan      499 non-null    object
#  11  nilai_penjualan    499 non-null    int64
# dtypes: int64(6), object(6)
# memory usage: 46.9+ KB

# %%
warmindo.describe().T
# Out:
#                  count          mean          std     min      25%      50%  \
# id               499.0    250.000000   144.193157     1.0    125.5    250.0
# invoice_id       499.0    250.000000   144.193157     1.0    125.5    250.0
# customer_id      499.0     48.016032    28.521811     1.0     22.0     48.0
# quantity         499.0      1.953908     0.796503     1.0      1.0      2.0
# harga_jual       499.0   9438.877756   496.748002  9000.0   9000.0   9000.0
# nilai_penjualan  499.0  18440.881764  7575.722958  9000.0  10000.0  18000.0
#
#                      75%      max
# id                 374.5    499.0
# invoice_id         374.5    499.0
# customer_id         72.5    100.0
# quantity             3.0      3.0
# harga_jual       10000.0  10000.0
# nilai_penjualan  27000.0  30000.0

# %%
warmindo.isna()
# Out:
#         id  invoice_id  tanggal_transaksi  customer_id  nama_produk  \
# 0    False       False              False        False        False
# 1    False       False              False        False        False
# 2    False       False              False        False        False
# 3    False       False              False        False        False
# 4    False       False              False        False        False
# ..     ...         ...                ...          ...          ...
# 494  False       False              False        False        False
# 495  False       False              False        False        False
# 496  False       False              False        False        False
# 497  False       False              False        False        False
# 498  False       False              False        False        False
#
#      jenis_produk  kategori_produk  quantity  harga_jual  jenis_pembayaran  \
# ...

# %%
warmindo.isna().sum()
# Out:
# id                   0
# invoice_id           0
# tanggal_transaksi    0
# customer_id          0
# nama_produk          0
# jenis_produk         0
# kategori_produk      0
# quantity             0
# harga_jual           0
# jenis_pembayaran     0
# jenis_pesanan        0
# nilai_penjualan      0
# dtype: int64

# %%
# melihat ukuran data (baris,kolom)
warmindo.shape
# Out:
# (499, 12)

# %%
# mengecek typpe data
warmindo.dtypes
# Out:
# id                    int64
# invoice_id            int64
# tanggal_transaksi    object
# customer_id           int64
# nama_produk          object
# jenis_produk         object
# kategori_produk      object
# quantity              int64
# harga_jual            int64
# jenis_pembayaran     object
# jenis_pesanan        object
# nilai_penjualan       int64
# dtype: object

# %%
warmindo.duplicated().sum()
# Out:
# np.int64(0)

# %%
# jml data kosong/panjang baris dikali 100
(warmindo.isna().sum()/len(warmindo))*100
# Out:
# id                   0.0
# invoice_id           0.0
# tanggal_transaksi    0.0
# customer_id          0.0
# nama_produk          0.0
# jenis_produk         0.0
# kategori_produk      0.0
# quantity             0.0
# harga_jual           0.0
# jenis_pembayaran     0.0
# jenis_pesanan        0.0
# nilai_penjualan      0.0
# dtype: float64

# %%
# menghaps kolom yang memiliki missing value
# implace True itu permanen sebelumnya ikut gada
warmindo.dropna(inplace=False)
# Out:
#       id  invoice_id tanggal_transaksi  customer_id               nama_produk  \
# 0      1           1           4/11/22           44      Indomie Ayam Spesial
# 1      2           2            8/1/22           10      Indomie Ayam Spesial
# 2      3           3            4/3/22           62  Indomie Rasa Soto Betawi
# 3      4           4           3/19/22           48  Indomie Rasa Soto Padang
# 4      5           5           4/29/22           87   Indomie Rasa Sop Buntut
# ..   ...         ...               ...          ...                       ...
# 494  495         495           5/17/22           11         Indomie Baso Sapi
# 495  496         496            6/6/22           55    Indomie Goreng Spesial
# 496  497         497           7/14/22           25    Indomie Goreng Rendang
# 497  498         498           8/22/22           39      Indomie Goreng Pedas
# 498  499         499           6/21/22           79          Indomie Soto Mie
#
# ...

# %%
a = warmindo.copy(deep=True)

# %%
a.dropna(inplace=True)

# %%
warmindo = warmindo.dropna()

# %%
warmindo.isna(). sum()
# Out:
# id                   0
# invoice_id           0
# tanggal_transaksi    0
# customer_id          0
# nama_produk          0
# jenis_produk         0
# kategori_produk      0
# quantity             0
# harga_jual           0
# jenis_pembayaran     0
# jenis_pesanan        0
# nilai_penjualan      0
# dtype: int64

# %%
# !pip install openpyxl
# Out:
# ...
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %%
# nampilin kolom
warmindo.columns
# Out:
# Index(['id', 'invoice_id', 'tanggal_transaksi', 'customer_id', 'nama_produk',
#        'jenis_produk', 'kategori_produk', 'quantity', 'harga_jual',
#        'jenis_pembayaran', 'jenis_pesanan', 'nilai_penjualan'],
#       dtype='object')

# %%
# menampilkan kolom (file iris dengan kolom target)
warmindo['jenis_pembayaran']
# Out:
# 0         QRIS-OVO
# 1             CASH
# 2      QRIS-OTHERS
# 3             CASH
# 4         QRIS-OVO
#           ...
# 494           CASH
# 495     QRIS-GOPAY
# 496     QRIS-GOPAY
# 497      QRIS-DANA
# 498       QRIS-OVO
# Name: jenis_pembayaran, Length: 499, dtype: object

# %%
# variabel datanya . diikuti nama kolomnya (hanya bisa 1 kata)
warmindo.nama_produk
# Out:
# 0          Indomie Ayam Spesial
# 1          Indomie Ayam Spesial
# 2      Indomie Rasa Soto Betawi
# 3      Indomie Rasa Soto Padang
# 4       Indomie Rasa Sop Buntut
#                  ...
# 494           Indomie Baso Sapi
# 495      Indomie Goreng Spesial
# 496      Indomie Goreng Rendang
# 497        Indomie Goreng Pedas
# 498            Indomie Soto Mie
# Name: nama_produk, Length: 499, dtype: object

# %%
warmindo
# Out:
#       id  invoice_id tanggal_transaksi  customer_id               nama_produk  \
# 0      1           1           4/11/22           44      Indomie Ayam Spesial
# 1      2           2            8/1/22           10      Indomie Ayam Spesial
# 2      3           3            4/3/22           62  Indomie Rasa Soto Betawi
# 3      4           4           3/19/22           48  Indomie Rasa Soto Padang
# 4      5           5           4/29/22           87   Indomie Rasa Sop Buntut
# ..   ...         ...               ...          ...                       ...
# 494  495         495           5/17/22           11         Indomie Baso Sapi
# 495  496         496            6/6/22           55    Indomie Goreng Spesial
# 496  497         497           7/14/22           25    Indomie Goreng Rendang
# 497  498         498           8/22/22           39      Indomie Goreng Pedas
# 498  499         499           6/21/22           79          Indomie Soto Mie
#
# ...

# %%
iris.set_index("sepal_ratio", inplace=True)

# %%
iris.reset_index(drop = True, inplace=True)

# %%
iris_filename = "iris.csv"
iris = pd.read_csv(iris_filename)

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
# update
iris["sepal_ratio"] = iris["SepalLengthCm"]/ iris ["SepalWidthCm"]
print(iris.head())
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species  \
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
#
#    sepal_ratio
# 0     1.457143
# 1     1.633333
# 2     1.468750
# 3     1.483871
# 4     1.388889

# %%
# axis 1 (kolom) dan 0 (baris), karena mau ganti kolom 1
iris["petal_area"] = iris.apply(lambda row: row["PetalLengthCm"] * row["PetalWidthCm"], axis =1)
print(iris.head())
# Out:
#              Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# sepal_ratio
# 1.457143      1            5.1           3.5            1.4           0.2
# 1.633333      2            4.9           3.0            1.4           0.2
# 1.468750      3            4.7           3.2            1.3           0.2
# 1.483871      4            4.6           3.1            1.5           0.2
# 1.388889      5            5.0           3.6            1.4           0.2
#
#                  Species  petal_area
# sepal_ratio
# 1.457143     Iris-setosa        0.28
# 1.633333     Iris-setosa        0.28
# 1.468750     Iris-setosa        0.26
# 1.483871     Iris-setosa        0.30
# 1.388889     Iris-setosa        0.28

# %%
iris.head()
# Out:
#              Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# sepal_ratio
# 1.457143      1            5.1           3.5            1.4           0.2
# 1.633333      2            4.9           3.0            1.4           0.2
# 1.468750      3            4.7           3.2            1.3           0.2
# 1.483871      4            4.6           3.1            1.5           0.2
# 1.388889      5            5.0           3.6            1.4           0.2
#
#                  Species  petal_area
# sepal_ratio
# 1.457143     Iris-setosa        0.28
# 1.633333     Iris-setosa        0.28
# 1.468750     Iris-setosa        0.26
# 1.483871     Iris-setosa        0.30
# 1.388889     Iris-setosa        0.28

# %%
# mingdep belajar handling missing value (drop& imputasi), normalisasi
# cara drop itu ada yang berdasarkan baris dan juga kolom 
# (untuk data yg sedikit: penghapusan baris)
# drop kolom untuk data yang besar/banyak
# imputasi (ada banyak cara) = statistika deskriptif, interpolasi (data time series), KNN
# deskriptif : mean, mdian, modus (spreeet/kategorikal), avverage

# %%
# DEADLINE : 1 MINGGU
